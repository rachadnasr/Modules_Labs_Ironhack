# %% [markdown]
# ## Import the necessary libraries here:

# %%
! pip install stackapi
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for stackapi: filename=StackAPI-0.2.0-py3-none-any.whl size=5843 sha256=a4f6e84afadee241e3da3c2e83d513af296effd0baa1dd21e373ab698b0fe51a
#   Stored in directory: c:\users\rachad\appdata\local\pip\cache\wheels\de\58\fe\8bab7cf44d8b0bf32e46f1715df2ba8c97d475de95a20985ac
# Successfully built stackapi
# ...

# %%
from stackapi import StackAPI

# %%
from datetime import datetime

# %% [markdown]
# ### Question 1: Find the questions and answers of last month.

# %%
help(StackAPI)
# Out:
# Help on class StackAPI in module stackapi.stackapi:
#
# class StackAPI(builtins.object)
#  |  StackAPI(name=None, version='2.2', **kwargs)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, name=None, version='2.2', **kwargs)
#  |      The object used to interact with the Stack Exchange API
#  |
#  |      :param name: (string) **(Required)** A valid ``api_site_parameter``
#  |          (available from http://api.stackexchange.com/docs/sites) which will
#  |          be used to connect to a particular site on the Stack Exchange
#  |          Network.
#  |      :param version: (float) **(Required)** The version of the API you are connecting to.
#  |          The default of ``2.2`` is the current version
#  |      :param proxy: (dict) (optional) A dictionary of http and https proxy locations
#  |          Example:
#  |
#  |          .. code-block:: python
#  |
#  |              {'http': 'http://example.com',
#  |               'https': 'https://example.com'}
#  |
# ...

# %%
questions = SITE.fetch('questions', min=datetime(2023, 1, 1), max=datetime(2023, 1, 31))
questions
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 269,
#  'total': 0,
#  'items': [{'tags': ['sql',
#     'database',
#     'postgresql',
#     'intersect',
#     'sql-query-store'],
#    'owner': {'reputation': 1,
#     'user_id': 21085837,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/dac96ec52ec10100e1af10b851b2a8ee?s=256&d=identicon&r=PG',
#     'display_name': 'Olesia',
#     'link': 'https://stackoverflow.com/users/21085837/olesia'},
#    'is_answered': False,
#    'view_count': 14,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1674729805,
#    'creation_date': 1674728661,
#    'last_edit_date': 1674729726,
#    'question_id': 75244830,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75244830/i-receive-an-errorerror-syntax-error-at-or-near-intersect-in-my-postgresql',
# ...

# %%
questions_f = [item["title"] for item in questions["items"]]
questions_f
# Out:
# ['I receive an error(ERROR: syntax error at or near &quot;INTERSECT&quot;) in my postgresql query',
#  'How to create a pipe to format account numbers?',
#  'Problems referencing WinForm class member function from extern source files',
#  'How to allow an app to send HDMI-CEC command?',
#  'how do i fix this hydration errror',
#  'Stripe modelling prices that are a % of revenue of customer',
#  'Contents contained within &lt;ul&gt;&lt;/ul&gt; tags are not displayed by the browser',
#  'Finding the count of how many elements of list A appear before than in the similar but mixed list B',
#  'How to exclude a clickable element from the tab order',
#  'How can I get double signal from same variable?',
#  'Tests not discovered because of dependencies on local modules out of the project',
#  'nodejs server - how to load file in memory to use in Modules',
#  'Looping and skipping in bash',
#  'Is there a way to get a generic call to any UIButton&#39;s method selector?',
# ...

# %%
answers = SITE.fetch('answers', min=datetime(2023, 1, 1), max=datetime(2023, 1, 31))
answers
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 278,
#  'total': 0,
#  'items': [{'owner': {'reputation': 115543,
#     'user_id': 745903,
#     'user_type': 'registered',
#     'accept_rate': 74,
#     'profile_image': 'https://www.gravatar.com/avatar/50933f6638836741e620669b3940410e?s=256&d=identicon&r=PG',
#     'display_name': 'leftaroundabout',
#     'link': 'https://stackoverflow.com/users/745903/leftaroundabout'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1674729382,
#    'last_edit_date': 1674729382,
#    'creation_date': 1674728854,
#    'answer_id': 75244865,
#    'question_id': 75242681,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 15244,
#     'user_id': 4279155,
#     'user_type': 'registered',
#     'accept_rate': 55,
#     'profile_image': 'https://i.stack.imgur.com/Gve3F.png?s=256&g=1',
#     'display_name': 'Dominique',
# ...

# %%
#answer = [item["title"] for item in questions["items"]]
#questions_f

# %% [markdown]
# ## Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
questions_voted = SITE.fetch('questions', fromdate=datetime(2023, 1, 25), todate=datetime(2023, 1, 27), tagged='python', sort='votes', min = 5)
questions_voted
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 265,
#  'total': 0,
#  'items': [{'tags': ['python', 'python-3.x', 'data-science', 'openai', 'jina'],
#    'owner': {'reputation': 93,
#     'user_id': 20550057,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/f8983e72b552c2f0594e2667754fc588?s=256&d=identicon&r=PG',
#     'display_name': 'Shaiming Yen',
#     'link': 'https://stackoverflow.com/users/20550057/shaiming-yen'},
#    'is_answered': False,
#    'view_count': 29,
#    'answer_count': 0,
#    'score': 7,
#    'last_activity_date': 1674661812,
#    'creation_date': 1674661666,
#    'last_edit_date': 1674661812,
#    'question_id': 75236433,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75236433/runtimeerror-quotclamp-min-cpuquot-not-implemented-for-quothalfquot',
# ...

# %%
questionvote = [item["title"] for item in questions_voted["items"]]
questionvote
# Out:
# ['RuntimeError: &amp;quot;clamp_min_cpu&amp;quot; not implemented for &amp;quot;Half&amp;quot;',
#  'Why does Python logging throw an error when a handler name starts with `s`?']

# %% [markdown]
# ## Question 3: Find the answers with id 6784 and 6473.

# %%
answers_id = SITE.fetch('answers', ids=['6784', '6473'])
answers_id
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 258,
#  'total': 0,
#  'items': [{'owner': {'reputation': 30551,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=256&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778,
#    'content_license': 'CC BY-SA 2.5'}]}

# %%
#it seems like only one ID is found (id = 6784)
