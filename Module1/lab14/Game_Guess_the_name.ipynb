# %%
###Choose the level of the game

list_level=["1","2","3"]
print("                 WELCOME TO THE GAME: GUESS THE NUMBER") 
print("\nEntrer 1 for Easy level \nEntrer 2 for Medium level \nEntrer 3 for Hard level")
level=input("\nChoose the level of the game: ")
while level not in list_level:
    level=input("\nThe level is not correct, choose only the number 1,2 or 3 : ")
    
if level=="1":
    print("\n           YOU CHOSE THE EASY LEVEL \n               LET'S GO - Just 5 attempts")
    x=1
    y=10
    trial=5
elif level=="2":
    print("\n           YOU CHOSE THE MEDIUM LEVEL \n              LET'S GO - Just 7 attempts")
    x=10
    y=100 
    trial=7
elif level=="3":
    print("\n           YOU CHOSE THE HARD LEVEL \n                 LET'S GO - Just 10 attempts")
    x=-500
    y=500
    trial=10
    
###Choose a random number (guess)
import random
#print(x,y)
number=random.randint(x,y)  

###Guess a number:
count=0
while count < trial:
    try:
        guess = int(input(f"\nGuess the number between {x} and {y} : "))
        if not x <= guess <= y:
            print("\nInvalid input! The number should be between ",x," and ",y," :  ")
        elif guess > number:
            print("\n ",count+1," attempt - Too high, try again. Hint: the number is less than {}.".format(guess))
        elif guess < number:
            print("\n ",count+1," attempt - Too low, try again. Hint: the number is greater than {}.".format(guess))
        else:
            print("\n            YOU GUESSED IT! The number was", number, "with ",count+1, "attempts")
            break
        count += 1
    except ValueError:
        print("\nInvalid input! Please enter a number.")
else:
    print("\n             YOU LOST THE GAME \nYou have reached the maximum number of attempts. \nThe number was", number)
# Out:
#                  WELCOME TO THE GAME: GUESS THE NUMBER
#
# Entrer 1 for Easy level
# Entrer 2 for Medium level
# Entrer 3 for Hard level
#
# Choose the level of the game: 3
#
#            YOU CHOSE THE HARD LEVEL
#                  LET'S GO - Just 10 attempts
#
# Guess the number between -500 and 500 : 1
#
#   1  attempt - Too high, try again. Hint: the number is less than 1.
#
# Guess the number between -500 and 500 : 6250
#
# Invalid input! The number should be between  -500  and  500  :
#
# Guess the number between -500 and 500 :
#
# Invalid input! Please enter a number.
#
# Guess the number between -500 and 500 : -250
#
#   3  attempt - Too high, try again. Hint: the number is less than -250.
#
# Guess the number between -500 and 500 : -125
#
#   4  attempt - Too high, try again. Hint: the number is less than -125.
#
# Guess the number between -500 and 500 : -60
#
#   5  attempt - Too high, try again. Hint: the number is less than -60.
#
# Guess the number between -500 and 500 : -5
#
#   6  attempt - Too high, try again. Hint: the number is less than -5.
#
# Guess the number between -500 and 500 : -3
#
#   7  attempt - Too high, try again. Hint: the number is less than -3.
#
# Guess the number between -500 and 500 : -300
#
#   8  attempt - Too high, try again. Hint: the number is less than -300.
#
# Guess the number between -500 and 500 : -450
#
#   9  attempt - Too high, try again. Hint: the number is less than -450.
#
# Guess the number between -500 and 500 : -34
#
#   10  attempt - Too high, try again. Hint: the number is less than -34.
#
#              YOU LOST THE GAME
# You have reached the maximum number of attempts.
# The number was -451
