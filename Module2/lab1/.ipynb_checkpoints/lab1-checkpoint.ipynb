# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import math

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.figure(figsize=(4,4))
plt.plot(x, y, color = "#2ebf66", label = 'plot(x,y)')
plt.plot(x, z, color = "blue", label = 'plot(x,z)')
plt.title("plot (x,y)")
plt.xlabel("x variable")
plt.ylabel("y variable")
plt.legend()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, axes = plt.subplots(1,2)
axes[0].plot(x, y, color = "#2ebf66", label = 'plot(x,y)')
axes[1].plot(x, z, color = "blue", label = 'plot(x,z)')

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, axes = plt.subplots(1,2,figsize = (7,4))
axes[0].plot(x, y, color = "#2ebf66", label = 'plot(x,y)')
axes[0].set_title('Linear plot x,y', fontsize=9, fontweight = 'light', color = '#2ebf66')
axes[1].plot(x, z, color = "blue", label = 'plot(x,z)')
axes[1].set_title('Linear plot x,z', fontsize=9, fontweight = 'light', color = "blue")

fig.suptitle('Lab1_Challenge1', fontsize=15)
# Out:
# Text(0.5, 0.98, 'Lab1_Challenge1')

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here #I should add them at the same plot
fig2, axes = plt.subplots(1,2,figsize = (9,5))
axes[0].plot(x, 𝑥**2, color = "red", label = 'plot(x2)')
axes[0].set_title('normal scale y=x2', fontsize=9, fontweight = 'light', color = "red")
axes[1].plot(x, np.exp(-x / 5.0), color = "black", label = 'plot(ex)')
axes[1].set_title('Log scale y=ex', fontsize=9, fontweight = 'light', color = "black")
fig2.suptitle('Lab1_Challenge1', fontsize=15)
# Out:
# Text(0.5, 0.98, 'Lab1_Challenge1')

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
fig2, axes = plt.subplots(1,2,figsize = (9,5))
axes[0].plot(x, 𝑥**2, color = "red", label = 'plot(x2)')
axes[0].set_title('normal scale y=x2', fontsize=9, fontweight = 'light', color = "red")
axes[1].plot(x, np.exp(-x / 5.0), color = "black", label = 'plot(ex)')
axes[1].set_title('Log scale y=ex', fontsize=9, fontweight = 'light', color = "black")
fig2.legend()
fig2.suptitle('Lab1_Challenge1', fontsize=15)
fig.subplots_adjust(wspace =0.5) #space between the plots

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv("Fitbit2.csv")
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED  #calculate the median and plot it
# your code here

plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.title('average steps per months', size='15', fontweight='bold')

sns.boxplot(x = fitbit['Months_encoded'],y = fitbit['Steps'])

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

plt.subplot(1,2,2)
plt.title('average steps per Work or Weekend', size='15', fontweight='bold')

sns.boxplot(x = fitbit['Work_or_Weekend'],y = fitbit['Steps'])
# Out:
# <AxesSubplot:title={'center':'average steps per Work or Weekend'}, xlabel='Work_or_Weekend', ylabel='Steps'>

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
col_int = ["Minutes Lightly Active", "Minutes Very Active", "Minutes Sedentary"]
count=1
for i in col_int:
    plt.subplot(2,2,count)
    fig.subplots_adjust(wspace = 0.3, hspace = 0.3)
    sns.scatterplot(fitbit["Steps"],fitbit[i])
    count+=1

plt.show()
# Out:
# C:\Users\Rachad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Rachad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Rachad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv("titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
num_col = titanic.select_dtypes(include=['int', 'float'])
num_col
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
obj_col = titanic.select_dtypes(include=['object'])
obj_col
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
fig = plt.figure(figsize=(12,6))
plt.style.use("classic")

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
fig, axes = plt.subplots(1, figsize=(12, 6), sharex=True)
sns.distplot(titanic.Age)
# Out:
# C:\Users\Rachad\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
#Also could be done 
# your code here
titanic_age = titanic.Age.value_counts().rename('count').sort_index()
titanic_age
sns.displot(titanic, x='Age')

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig, axes = plt.subplots(2,2,figsize=(12,6))

sns.distplot(titanic.Age, bins = 10, ax = axes[0,0])
axes[0,0].set_title('Distribution plot with bins 10')
sns.distplot(titanic.Age, bins = 20, ax = axes[1,0])
axes[1,0].set_title('Distribution plot with bins 20')
sns.distplot(titanic.Age, bins = 50, ax = axes[0,1])
axes[0,1].set_title('Distribution plot with bins 50')
# Out:
# C:\Users\Rachad\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Rachad\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The bins don't affect the form of the distribution however the higher the bins the better the precision to determine the mean and the stds
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.distplot(titanic.Age)
# Out:
# C:\Users\Rachad\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
titanic_gender = titanic.Gender.value_counts()
plt.figure(figsize=(4,4))
plt.bar(titanic_gender.index, titanic_gender, color = ('green', 'blue'))
# Out:
# <BarContainer object of 2 artists>

# %%
# Method 2 - seaborn
# your code here
sns.histplot(data=titanic, x="Gender", bins = 1,shrink=0.7, hue ="Gender")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.histplot(data=titanic, x="Pclass", binrange=(0,4), shrink=4)
#sns.countplot(data = titanic,  x='pClass')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
desc_stats = titanic["Age"].describe().reset_index() 
desc_stats = desc_stats[desc_stats['index'] != 'count']
for i in num_col:  
    if i in ['Age']:    
        continue  
        sns.factorplot(x='index', y=i, data = desc_stats)  
        plt.show()

# %%
sns.set(style="darkgrid")
sns.boxplot(x="Age",data=titanic, width = 0.3)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
most people are between 20 and 40
few people are higher than 60

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
sns.set(style="darkgrid")
fig, (ax_box, ax_dist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.18, .85)})
sns.boxplot(titanic["Age"], ax = ax_box)
sns.distplot(titanic.Age, color = 'red', ax = ax_dist)
ax_box.set(xlabel='')
plt.show()
# Out:
# C:\Users\Rachad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Rachad\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
sns.scatterplot(x=titanic.Age,y=titanic.Fare)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
# Method 2 - seaborn
# your code here
sns.scatterplot(data=titanic, x= "Age", y="Fare")
sns.lmplot(data=titanic, x= "Age", y="Fare")

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
sns.heatmap(titanic.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
The most positively correlated are SibSp and Parch with a correlation of 0.373587
Fare and Pclass are the most anti correlated
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.boxplot(x="Pclass", y="Age", data=titanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
sns.set_palette('RdYlGn') #choosing the group or theme of colors 
palette_alive = {"male": "C5", "female": "C0"}
sns.displot(titanic, x="Age", hue="Gender", palette = palette_alive, element="step")
